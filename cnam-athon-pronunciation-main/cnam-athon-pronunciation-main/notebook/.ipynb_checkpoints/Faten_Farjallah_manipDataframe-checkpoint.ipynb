# %%
import pandas as pd

# %%
#importer le fichier Buchanan
dfDicoBuch = pd.read_csv("./../data/dictionary/1757_Buchanan-J.csv", delimiter=";", encoding="utf8")
dfDicoBuch.sample(n=5)
# Out:
#        nbSyll           pron origin warning remarques POS  lineId  pageId
# 15449       3       waʹtĕred    NaN     NaN       NaN  a.    47.0     236
# 12936       1          ſprăt    NaN     NaN       NaN  n.    42.0     201
# 6484        2     jĕʹrg_u_er    NaN     NaN       NaN  n.    39.0     111
# 9196        4  nūtrĭʹti_o_us     L.     NaN       NaN  a.    29.0     149
# 5882        1          grīce    NaN     NaN       NaN  n.    41.0     101

# %%
#importer le fichier PronChar
PronChar = pd.read_csv("./../data/dictionary/Buchanan_PronChar_counts.csv", delimiter=";", encoding="utf8")
PronChar.sample(n=50)

# %%
PronChar.fillna('', inplace=True)

# %%
PronChar.sample(n=50)
# Out:
#    char    occ graph
# 32    ȯ    371     o
# 21    y   1952     y
# 8     t   8790     t
# 69    I      1     l
# 42    ̆    132     o
# 7     f   1809     f
# 1     ʹ  12725
# 40    x    406     x
# 2     b   2288     b
# 53    (     28
# 55    é      7     e
# 4     c   5500     c
# 36    w    796     w
# 17    _   4124
# 25    ō    542     o
# 45    -     31     -
# 58    í      2     i
# 24    ĭ   5281     i
# 11    n   8612     n
# 14    d   3758     d
# 39    q    270     q
# 18    m   3639     m
# 50    ė     83     e
# 16    ŏ   2797     o
# 28    l   6260     l
# 54    )     28
# 68    á      1     a
# 29    ū   1321     u
# 22    r   9245     r
# 52          57
# 0     a   3207     a
# 10    ſ   4329     s
# 34    ŭ   2085     u
# 43    æ     11     æ
# 23    v   1477     v
# 35    ē    493     e
# 60    â      5     a
# 57    г      1     r
# 6     s   2935     s
# 59    ˙      3
# 20    ĕ   4262     e
# 46    è     73     e
# 70    х      2     x
# 30    p   3775     p
# 56    а      2     a
# 5     u   1623     u
# 67    ;      3
# 3     ă   4533     a
# 31    g   2604     g
# 51    ȧ     54     a

# %%
# a modifier (les noms des variables et fonctions)
def sampa2ipa(strSampa, dfMapping):
    ipaRes = ""
    
    for valSampa in strSampa:
        #print(valSampa)
        dfRowFinded = dfMapping[dfMapping['char']==valSampa]

        if len(dfRowFinded==1):
            ipaRes+=dfRowFinded.iloc[0]['graph']
        else:
            ipaRes+='?'
    return ipaRes

# %%
#dfDicoBuch['motVedette'] = dfDicoBuch.apply(lambda x: sampa2ipa(x['graph'], PronChar),1)

# %%
dfDicoBuch['motVedette'] = dfDicoBuch.apply(lambda x: sampa2ipa(x['pron'], PronChar),1)

# %%
dfDicoBuch['motVedette']
# Out:
# 0           abacus
# 1            abaft
# 2        abaisance
# 3          abandon
# 4        abandoned
#            ...
# 15795    zoography
# 15796    zoophytes
# 15797    zoophoric
# 15798    zootomist
# 15799       zotica
# Name: motVedette, Length: 15800, dtype: object

# %%
dfDicoBuch.sample(n=10)
# Out:
#        nbSyll          pron origin warning remarques POS  lineId  pageId  \
# 124         4     ăʹcrĭmony     L.     NaN       NaN  n.    18.0      21
# 4197        2         eaʹſy     F.     NaN       NaN  a.     5.0      78
# 9645        2       păʹllăs    NaN     NaN       NaN  n.    37.0     155
# 11452       3   rĕmĕʹmb_e_r    NaN     NaN       NaN  v.    68.0     180
# 3149        3      cūrāʹtor    NaN     NaN       NaN  n.    26.0      63
# 9465        3        ōʹrĭon    NaN     NaN       NaN  n.    13.0     153
# 2124        1        cheeſe    NaN     NaN       NaN  n.     6.0      49
# 2845        5  cŏnvŏcāʹtion     L.     NaN       NaN  n.    10.0      59
# 8492        3     mĕʹſsŭage    NaN     NaN       NaN  n.    41.0     139
# 14628       4    ŭʹlcĕrāted    NaN     NaN       NaN  a.    14.0     225
#
#         motVedette
# 124       acrimony
# 4197          easy
# 9645        pallas
# 11452     remember
# 3149       curator
# 9465         orion
# 2124        cheese
# 2845   convocation
# 8492      messuage
# 14628    ulcerated

# %%
#importer le fichier BigiRichSample
BigiRichSample=pd.read_csv("./../data/dataframe/BigiRichSample.csv", delimiter=";", encoding="utf8")

# %%
BigiRichSample.sample(n=5)
# Out:
#               hwd           pronSampa         ipa
# 889        murali        m 3:r A l i:    mɜ:rɑliː
# 227          jade             dZ eI d         ??d
# 284      simpkins     s I m p k i n z    sɪmpkinz
# 785       foreman       f O: r\ m @ n     fOːɹmən
# 662  kjellberg(2)  k @ dZ E l b 3:r g  kə?ɛlbɜ:rg

# %%
#jointure des deux tables
datej= pd.merge(dfDicoBuch, BigiRichSample, left_on='motVedette', right_on='hwd',how='left')

# %%
datej.sample(20)
# Out:
#        nbSyll            pron origin warning remarques POS  lineId  pageId  \
# 9384        2         oʹp_e_n    NaN     NaN       NaN  v.     4.0     152
# 11380       3       rĕʹgĭcīde    NaN     NaN       NaN  n.    68.0     179
# 6825        5  incŏnvĕʹrſable     F.     NaN       NaN  a.    19.0     116
# 9428        2           ōʹral    NaN     NaN       NaN  a.    48.0     152
# 10475       3        prāʹvĭty    NaN     NaN       NaN  n.    18.0     167
# 7379        1            jōve    NaN     NaN       NaN  n.    69.0     123
# 8949        1             năg    NaN     NaN       NaN  n.     6.0     145
# 3546        2         detaiʹn     L.     NaN       NaN  v.    70.0      68
# 14389       2         văʹſſal    NaN     NaN       NaN  n.    60.0     221
# 7089        3      iʹnnŏcĕnce     L.     NaN       NaN  n.    67.0     119
# 13360       5    sūpĕrsēʹdėȧs    NaN     NaN       NaN  n.    33.0     207
# 14313       1           twĭſt    NaN     NaN       NaN  n.    54.0     220
# 10894       2       pŭʹnctūre     L.     NaN       NaN  n.     5.0     173
# 10138       1          pierce     F.     NaN       NaN  v.    41.0     162
# 8126        3       măgnĕʹtic    NaN     NaN       NaN  a.    35.0     134
# 4637        6    evăpŏrāʹtion    NaN     NaN       NaN  n.    13.0      84
# 10627       5  prīmŏgĕʹnĭtūre    NaN     NaN       NaN  n.    26.0     169
# 5193        2     fōʹr_e_mŏſt    NaN     NaN       NaN  a.    67.0      91
# 4470        2          ĕnsūeʹ    NaN     NaN       NaN  v.    61.0      81
# 335         3       ăʹlkăhĕſt    NaN     NaN       NaN  n.    13.0      24
#
#           motVedette  hwd pronSampa  ipa
# 9384            open  NaN       NaN  NaN
# 11380       regicide  NaN       NaN  NaN
# 6825   inconversable  NaN       NaN  NaN
# 9428            oral  NaN       NaN  NaN
# 10475        pravity  NaN       NaN  NaN
# 7379            jove  NaN       NaN  NaN
# 8949             nag  NaN       NaN  NaN
# 3546          detain  NaN       NaN  NaN
# 14389         vassal  NaN       NaN  NaN
# 7089       innocence  NaN       NaN  NaN
# 13360    supersedeas  NaN       NaN  NaN
# 14313          twist  NaN       NaN  NaN
# 10894       puncture  NaN       NaN  NaN
# 10138         pierce  NaN       NaN  NaN
# 8126        magnetic  NaN       NaN  NaN
# 4637     evaporation  NaN       NaN  NaN
# 10627  primogeniture  NaN       NaN  NaN
# 5193        foremost  NaN       NaN  NaN
# 4470           ensue  NaN       NaN  NaN
# 335         alkahest  NaN       NaN  NaN

# %%
#datej[datej['hwd'] =='castor']

# %%
#bonus

# %%
#sauvegarde 
datej.to_csv("./../data/dataframe/BuchananRich.csv",sep=";",encoding="utf8",index=False)

# %%
#fait le bonus (notes papier)
#renommer variable et fonctions, fait des titres
